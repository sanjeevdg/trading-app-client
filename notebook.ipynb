# %% [markdown]
# # CSV Viewer Notebook
# This notebook loads and displays a CSV file for the React frontend.

# %%
import pandas as pd

# Path to your CSV file
csv_path = 'data/bars_5Min.csv'

df = pd.read_csv(csv_path)

df.head()

# %%
# Display dataframe information
df.info()

# %%
# Show summary statistics
df.describe()

# %%
# Optional visualization
import matplotlib.pyplot as plt

df.plot()
plt.show()
